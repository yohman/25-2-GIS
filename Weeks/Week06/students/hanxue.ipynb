# %% [markdown]
# This is a map I made of science museums located in Tokyo, you can use it to find museums you are interested in.

# %%
import folium
NationalMuseumofNatureandScience =[35.7168, 139.7767]
m = folium.Map(location=NationalMuseumofNatureandScience, zoom_start=11)
folium.Marker(NationalMuseumofNatureandScience, popup=123, tooltip="NationalMuseumofNatureandScience").add_to(m)
Miraikan =[35.6198, 139.7763]
TenQ =[35.7039, 139.7520]
GALAXCITY =[35.7805, 139.7905]
TEPIAAdvancedTechnologyHall =[35.6778, 139.7162]
KatsushikaCityMuseum =[35.7533, 139.8427]
NationalMuseumofNatureandScience =[35.7168, 139.7767]
folium.Marker(Miraikan, popup=234, tooltip="Miraikan").add_to(m)
folium.Marker(TenQ, popup=345, tooltip="TenQ").add_to(m)
folium.Marker(GALAXCITY,popup=456, tooltip="GALAXCITY").add_to(m)
folium.Marker(TEPIAAdvancedTechnologyHall,popup=567, tooltip="TEPIAAdvancedTechnologyHall").add_to(m)
folium.Marker(KatsushikaCityMuseum,popup=678, tooltip="KatsushikaCityMuseum").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
