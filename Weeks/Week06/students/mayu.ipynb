# %% [markdown]
# # **<span style="color: orange; ">東京近郊のひまわりの名所🌻</span>**
# ***
#
# <span style="color: green; ">ひまわり畑を楽しむの7月下旬～8月上旬頃がおすすめです！</span>
# ![Himawari](images/Himawari.jpg)
#
#
#
#
#
# 1. 【立川】「国営昭和記念公園」
# 2. 【清瀬】「清瀬ひまわりフェスティバル」
# 3. 【神奈川】「座間市ひまわり畑」
# 4. 【千葉】「成田ゆめ牧場」
# 5. 【千葉】「あけぼの山農業公園」
# 6. 【埼玉】「伊佐沼公園」

# %%
#1
import folium
#2.1　東京
立川= [35.711601698938836, 139.393910354076]
清瀬= [35.78294299837545, 139.53984488483826]
#2.2　東京近郊
神奈川= [35.48606991493962, 139.377999407649]
千葉= [35.87119363060956, 140.3985650043385]
千葉= [35.896351836529426, 140.00595301060628]
埼玉= [35.92264595903607, 139.514064739271]
#3
m = folium.Map(location=立川, zoom_start=9)
#4.1　東京
folium.Marker(立川, popup="大人の背丈を超えるひまわりがある", tooltip="国営昭和記念公園").add_to(m)
folium.Marker(清瀬, popup="約10万本ものひまわり", tooltip="清瀬ひまわりフェスティバル").add_to(m)
#4.2 東京近郊
folium.Marker(神奈川, popup="約55万本のひまわりが咲く🌻", tooltip="座間市ひまわり畑").add_to(m)
folium.Marker(千葉, popup="かわいい動物もいる🐮", tooltip="成田ゆめ牧場").add_to(m)
folium.Marker(千葉, popup="麗澤から近い！", tooltip="あけぼの山農業公園").add_to(m)
folium.Marker(埼玉, popup="穴場で落ち着いた雰囲気", tooltip="伊佐沼公園").add_to(m)

#5
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
