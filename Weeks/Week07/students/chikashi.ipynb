# %% [markdown]
# My map
#
# この地図は麗澤大学内の施設と近くにある便利な施設です
# 1,かえで
# 2,あすなろ
# 3,ひいらぎ
# 4,図書館
# 5,駐車場
# 6,部室棟
# 7,セブンイレブン
# 8,モスカフェ
# 9,光が丘小学校
# 10,交番

# %%
# import folium, a leaflet python library
import folium

# create a list of lat/lon pair for UCLA
reitaku = [35.8330, 139.9550]

kaede = [35.83304899572845, 139.9550263688704]
asunaro = [35.83218389343381, 139.9559046419524]
hiiragi = [35.83432746243043, 139.95492044150396]
library = [35.83288620720931, 139.9560383893833]
parking = [35.83477548217266, 139.9561361979999]
bukastu = [35.83480867733186, 139.95489801198133]


seven = [35.83153177619921, 139.95615584329036]
moscafe = [35.831142717397036, 139.95596014665873]
primary = [35.83637864291207, 139.95583678516158]
police = [35.83038280781122, 139.95595654760183]

# make the map
m = folium.Map(location=reitaku, zoom_start=16)

# library import
import pandas as pd
import folium
import matplotlib.pyplot as plt

# import the csv file
df = pd.read_csv('mydeta2.csv')

# add basemaps
folium.TileLayer(name='2007年以降',tiles='https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1987年～1990年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1984年～1986年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1979年～1983年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1974年～1978年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1961年～1969年',tiles='https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png',attr='国土地理院').add_to(m)

# basemapが選べるボタンをマップに足す
folium.LayerControl().add_to(m)


# df をループしてマーカーを作る
for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, 
                  popup='<div style="width:150px">'+row['description']+'</div>', 
                  tooltip=row['name'],
                  icon=folium.Icon(color=row['color']
                )).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e8eb83e7ac68585a3d9b1f45cdd8371 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e8eb83e7ac68585a3d9b1f45cdd8371&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e8eb83e7ac68585a3d9b1f45cdd8371 = L.map(
#                 &quot;map_9e8eb83e7ac68585a3d9b1f45cdd8371&quot;,
#                 {
#                     center: [35.833, 139.955],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fce27619ad60c8979e621d8951bd337 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e8eb83e7ac68585a3d9b1f45cdd8371);
#
#
#             var tile_layer_386a80b027910b5149e71234061ee68a = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e8eb83e7ac68585a3d9b1f45cdd8371);
#
#
#             var tile_layer_8109a71b9b97c61dc22b087dd5435236 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e8eb83e7ac68585a3d9b1f45cdd8371);
#
#
#             var tile_layer_2d7ebcf46aa1df71c9286377ed189c8c = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e8eb83e7ac68585a3d9b1f45cdd8371);
#
#
#             var tile_layer_18cefd4bad3efffdbd2fe4282250317d = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e8eb83e7ac68585a3d9b1f45cdd8371);
#
#
#             var tile_layer_af28eb182ddd8798434c398c545513e1 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e8eb83e7ac68585a3d9b1f45cdd8371);
#
#
#             var tile_layer_226aa927c1542ffb0f8844a830a86f92 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e8eb83e7ac68585a3d9b1f45cdd8371);
#
#
#             var layer_control_c391fabbfb24693c2e4966b6a3453183 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_1fce27619ad60c8979e621d8951bd337,
#                     &quot;2007\u5e74\u4ee5\u964d&quot; : tile_layer_386a80b027910b5149e71234061ee68a,
#                     &quot;1987\u5e74\uff5e1990\u5e74&quot; : tile_layer_8109a71b9b97c61dc22b087dd5435236,
#                     &quot;1984\u5e74\uff5e1986\u5e74&quot; : tile_layer_2d7ebcf46aa1df71c9286377ed189c8c,
#                     &quot;1979\u5e74\uff5e1983\u5e74&quot; : tile_layer_18cefd4bad3efffdbd2fe4282250317d,
#                     &quot;1974\u5e74\uff5e1978\u5e74&quot; : tile_layer_af28eb182ddd8798434c398c545513e1,
#                     &quot;1961\u5e74\uff5e1969\u5e74&

# %% [markdown]
# 【プロセス】
# スプレッドシートを作る
# ↓
# csvデータをダウンロード、インポートする
# ↓
# import foliumと麗澤大学の位置をコピー
# ↓
# import pandas as pd
# import folium
# import matplotlib.pyplot as pltをコピぺする
# ↓
# # import the csv file
# df = pd.read_csv('mydeta.csv')をコピペし、mydeta2.csvに書き換える
# ↓
# 過去の地図データをコピペする
# ↓
# for index, row in df.iterrows():をコピぺする
# ↓
# プログラムを実行
#
# 【感想】
# プロセスではスムーズに解決しているように見えますが、実際はエラー文が何度も出てしまい、とても悩んでいました。
# エラーが起こったときは、エラー文をコピーしてchatGPTに聞くようにしました。
# chatGPTに聞くと問題点を理解できるし、どのように解決したらいいか理解することが出来ました。
# 今後もエラー文が起きた時、chatGPTに質問しながら解決していこうと思っています。
