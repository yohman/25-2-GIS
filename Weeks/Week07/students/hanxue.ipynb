# %% [markdown]
# 東京都内の有名地を紹介するマップ

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mydata.csv')

# %%
df
# Out:
#                                name
# 0  NationalMuseumofNatureandScience  \
# 1                          Miraikan
# 2                              TenQ
# 3                         GALAXCITY
# 4       TEPIAAdvancedTechnologyHall
# 5              KatsushikaCityMuseum
# 6                     Meiji Shrine
# 7                  Meiji University
# 8                        Tokyo Dome
# 9    Shinjuku Gyoen National Garden
#
#                                          description   latitude   longitude
# 0  The National Museum of Nature and Science (国立科...  35.716800  139.776700  \
# 1  日本科学未来館（にっぽんかがくみらいかん、英称：The National Museum of...  35.619800  139.776300
# 2  インタラクティブな展示、オーディオ ガイド、ギフトショップがあるクールでモダンな宇宙博物館。...  35.703900  139.752000
# 3  足立区こども未来創造館（あだちくこどもみらいそうぞうかん）はプラネタリウム上映を中心としたま...  35.780500   35.780500
# 4  テピア（TEPIA）[1]は、東京都港区北青山にある、機械・情報産業を中心とした技術の展示施...  35.677800  139.716200
# 5  葛飾の歴史をたどる郷土博物館と、星の世界をさぐる天文博物館が一つになった博物館。 郷土のフロ...  35.753300  139.842700
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         10 non-null     object
#  1   description  10 non-null     object
#  2   latitude     10 non-null     float64
#  3   longitude    10 non-null     float64
#  4   color        10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df[['name','latitude','longitude']]
# Out:
#                                name   latitude   longitude
# 0  NationalMuseumofNatureandScience  35.716800  139.776700
# 1                          Miraikan  35.619800  139.776300
# 2                              TenQ  35.703900  139.752000
# 3                         GALAXCITY  35.780500   35.780500
# 4       TEPIAAdvancedTechnologyHall  35.677800  139.716200
# 5              KatsushikaCityMuseum  35.753300  139.842700
# 6                     Meiji Shrine   35.676111  139.699167
# 7                  Meiji University  35.697250  139.761444
# 8                        Tokyo Dome  35.705833  139.751944
# 9    Shinjuku Gyoen National Garden  35.685278  139.709722

# %%
df['latitude']
# Out:
# 0    35.716800
# 1    35.619800
# 2    35.703900
# 3    35.780500
# 4    35.677800
# 5    35.753300
# 6    35.676111
# 7    35.697250
# 8    35.705833
# 9    35.685278
# Name: latitude, dtype: float64

# %%
df['longitude']
# Out:
# 0    139.776700
# 1    139.776300
# 2    139.752000
# 3     35.780500
# 4    139.716200
# 5    139.842700
# 6    139.699167
# 7    139.761444
# 8    139.751944
# 9    139.709722
# Name: longitude, dtype: float64

# %%
center_lat = df['latitude'].mean()
center_lon = df['longitude'].mean()

print(center_lat,center_lon)
# Out:
# 35.70165719999999 129.3566677

# %%
for index, row in df.iterrows():
    print(row['name'])
# Out:
# NationalMuseumofNatureandScience
# Miraikan
# TenQ
# GALAXCITY
# TEPIAAdvancedTechnologyHall
# KatsushikaCityMuseum
# Meiji Shrine
# Meiji University
# Tokyo Dome
# Shinjuku Gyoen National Garden

# %%
for index, row in df.iterrows():
    print(row['name'],row['latitude'],row['longitude'])
# Out:
# NationalMuseumofNatureandScience 35.7168 139.7767
# Miraikan 35.6198 139.7763
# TenQ 35.7039 139.752
# GALAXCITY 35.7805 35.7805
# TEPIAAdvancedTechnologyHall 35.6778 139.7162
# KatsushikaCityMuseum 35.7533 139.8427
# Meiji Shrine  35.676111 139.699167
# Meiji University 35.69725 139.761444
# Tokyo Dome 35.705833 139.751944
# Shinjuku Gyoen National Garden 35.685278 139.709722

# %%
m = folium.Map(location=[center_lat,center_lon], zoom_start=12)

for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, 
                  popup='<div style="width:150px">'+row['description']+'</div>', 
                  tooltip=row['name'],
                  icon=folium.Icon(color=row['color']
                )).add_to(m)
m
# Out:
# C:\Users\99556\AppData\Local\Temp\ipykernel_30372\341608195.py:8: UserWarning: color argument of Icon should be one of: {'orange', 'pink', 'darkred', 'lightred', 'green', 'gray', 'purple', 'darkpurple', 'blue', 'lightblue', 'darkgreen', 'cadetblue', 'beige', 'red', 'lightgray', 'black', 'darkblue', 'white', 'lightgreen'}.
#   icon=folium.Icon(color=row['color']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('<iframe frameborder="0" scrolling="no" marginheight="0" marginwidth="0" width="500" height="400" src="https://maps.gsi.go.jp/?hc=hic#12/35.69389/139.703613/&base=ort&ls=ort%7Cairphoto%7Cgazo1%7Cgazo2%7Cmodis%7Cnendophoto2022&blend=0000&disp=100111&vs=c1g1j0h0k0l0u0t0z0r0s0m0f1"></iframe>')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '<iframe frameborder="0" scrolling="no" marginheight="0" marginwidth="0" width="500" height="400" src="https://maps.gsi.go.jp/?hc=hic#12/35.69389/139.703613/&base=ort&ls=ort%7Cairphoto%7Cgazo1%7Cgazo2%7Cmodis%7Cnendophoto2022&blend=0000&disp=100111&vs=c1g1j0h0k0l0u0t0z0r0s0m0f1"></iframe>' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[16], line 1
# ...

# %% [markdown]
# 地図を作るのが難しいです。「ベースマップに現在と過去の衛星オプションを足す」についてはまだわからないです。来週の授業で学びたいです。
