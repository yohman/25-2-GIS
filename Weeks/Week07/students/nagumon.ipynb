# %% [markdown]
# 行ってみたい国

# %%
# library import
import pandas as pd #pdとしてインポートする
import folium
import matplotlib.pyplot as plt #plttpしてインポートする

# %%
# import the csv file
df = pd.read_csv('mydata2.csv')#dfにmydataのファイルを読み込んだ

# %%
df
# Out:
#       name                                        description   latitude
# 0      ソウル   韓流アイドルが好きなので、もしかしたら会えるかもしれない！韓国料理も好きなのでたくさん食べたい！  37.576222  \
# 1      セブ島                     暖かい島国に行きたい！物価も安いからたくさん豪遊したい！！！  10.311723
# 2    ホーチミン  ベトナムの人はめちゃめちゃ優しい！ベトナム料理は苦手だったけどクーシンサイは美味しかったから...  10.815368
# 3  カルフォルニア                  んと、西海岸？東海岸？どこか分からないけど有名だから行ってみたい！  34.073771
# 4      ハワイ                           アロハ〜！アサイーボウル食べたい！海で泳ぎたい！  21.304449
# 5       南極                  北極熊にあってみたい！南極にもいるのかな〜？寒さに打ち勝てるかな汗 -80.914875
# 6     シドニー                 物価は高さそうだけど、治安が良さそうなオーストラリアに行ってみたい！ -33.908236
# 7       台湾                      千と千尋の神隠しの題材になった場所を自分の目で見てみたい！  25.023509
# 8      トルコ                        サバがおすすめしてくれた！トルコアイスとか美味しそう！  39.927866
# 9   シンガポール                       かすみが行きたいって言ってた！マーライオンを見てみたい！   1.359622
#
#     longitude       color
# 0  126.995973      purple
# 1  123.901398  lightgreen
# 2  106.663268         red
# 3 -118.310116    darkblue
# 4 -157.858788       white
# 5   53.661239    lightred
# 6  151.184382        pink
# 7  121.555747   darkgreen
# 8   32.850999  darkpurple
# 9  103.868532   lightgray

# %%
df['latitude'].to_list()
# Out:
# [37.57622236,
#  10.31172276,
#  10.81536833,
#  34.07377082,
#  21.30444868,
#  -80.91487467,
#  -33.90823591,
#  25.02350853,
#  39.92786579,
#  1.359621696]

# %%
df['longitude'].to_list()
# Out:
# [126.9959729,
#  123.901398,
#  106.6632677,
#  -118.3101157,
#  -157.8587884,
#  53.66123861,
#  151.1843823,
#  121.5557466,
#  32.8509987,
#  103.8685323]

# %%
# size of the data (rows, columns)
df.shape#5行のデータ
# Out:
# (10, 5)

# %%
# list of columns
df.columns.to_list()
# Out:
# ['name', 'description', 'latitude', 'longitude', 'color']

# %%
# put those values in a list/リストに入れることができる
df['latitude'].to_list()
# Out:
# [37.57622236,
#  10.31172276,
#  10.81536833,
#  34.07377082,
#  21.30444868,
#  -80.91487467,
#  -33.90823591,
#  25.02350853,
#  39.92786579,
#  1.359621696]

# %%
# summary stats/describeは統計
df['latitude'].describe()
# Out:
# count    10.000000
# mean      6.556942
# std      37.623112
# min     -80.914875
# 25%       3.597647
# 50%      16.059909
# 75%      31.811205
# max      39.927866
# Name: latitude, dtype: float64

# %%
# summary stats
df['longitude'].describe()
# Out:
# count     10.000000
# mean      54.451263
# std      107.756810
# min     -157.858788
# 25%       38.053559
# 50%      105.265900
# 75%      123.314985
# max      151.184382
# Name: longitude, dtype: float64

# %%
# mean 平均値
df['latitude'].mean()
# Out:
# 6.556941838600001

# %%
# median 中央値
df['latitude'].median()
# Out:
# 16.059908505

# %%
# get center lat/lon
center_lat = df['latitude'].mean()
center_lon = df['longitude'].mean()

print(center_lat,center_lon)#中心のポイントができる。経度と緯度の真ん中が分かる
# Out:
# 6.556941838600001 54.451263301

# %%
# make the map
m = folium.Map(location=[center_lat,center_lon], zoom_start=2)

# df をループしてマーカーを作る
for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, 
                  popup='<div style="width:150px">'+row['description']+'</div>', 
                  tooltip=row['name'],
                  icon=folium.Icon(color=row['color']
                )).add_to(m)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c49543efd3b5770b043288053de6d7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c49543efd3b5770b043288053de6d7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c49543efd3b5770b043288053de6d7d = L.map(
#                 &quot;map_7c49543efd3b5770b043288053de6d7d&quot;,
#                 {
#                     center: [6.556941838600001, 54.451263301],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32655d098b82b1d0afb1c37b3bf908c4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7c49543efd3b5770b043288053de6d7d);
#
#
#             var marker_89b7ca1a955644d4dbab85f5ac4b83db = L.marker(
#                 [37.57622236, 126.9959729],
#                 {}
#             ).addTo(map_7c49543efd3b5770b043288053de6d7d);
#
#
#             var icon_ec5535d5c0dc9be908acbc657e867835 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89b7ca1a955644d4dbab85f5ac4b83db.setIcon(icon_ec5535d5c0dc9be908acbc657e867835);
#
#
#         var popup_98af53ce30c1cce086bb1c5342b1d736 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d0810fe33b4395b7135d3fcad117f13 = $(`&lt;div id=&quot;html_4d0810fe33b4395b7135d3fcad117f13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:150px&quot;&gt;韓流アイドルが好きなので、もしかしたら会えるかもしれない！韓国料理も好きなのでたくさん食べたい！&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_98af53ce30c1cce086bb1c5342b1d736.setContent(html_4d0810fe33b4395b7135d3fcad117f13);
#
#
#
#         marker_89b7ca1a955644d4dbab85f5ac4b83db.bindPopup(popup_98af53ce30c1cce086bb1c5342b1d736)
#         ;
#
#
#
#
#             marker_89b7ca1a955644d4dbab85f5ac4b83db.bindTooltip(
#                 `&lt;div&gt;
#                      ソウル
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_49d4cbeb5687c53594e54a06a46bea8f = L.marker(
#                 [10.31172276, 123.901398],
#                 {}
#             ).addTo(map_7c49543efd3b5770b043288053de6d7d);
#
#
#             var icon_2213b1ca3a724e6bd894e7d1a8716e88 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_49d4cbeb5687c53594e54a06a46bea8f.setIcon(icon_2213b1ca3a724e6bd894e7d1a8716e88);
#
#
#         var popup_8c6b23db0e82a2b781eba07f3c63aa34 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5e6004eece06f1530182cb054a2c879 = $(`&lt;div id=&quot;html_b5e6004eece06f1530182cb054a2c879&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:150px&quot;&gt;暖かい島国に行きたい！物価も安いからたくさん豪遊したい！！！&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_8c6b23db0e82a2b781eba07f3c63aa34.setContent(html_b5e6004eece06f1530182cb054a2c879);
#
#
#
#         marker_49d4cbeb5687c53594e54a06a46bea8f.bindPopup(popup_8c6b23db0e82a2b781eba07f3c63aa34)
#         ;
#
#
#
#
#             marker_49d4cbeb5687c53594e54a06a46bea8f.bindTooltip(
#                 `&lt;div&gt;
#                      セブ島
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c256f4de9ef2f8b48d0d2fa1b228dbdd = L.marker(
#                 [10.81536833, 106.6632677],
#                 {}
#             ).addTo(map_7c49543efd3b5770b043288053de6d7d);
#
#
#             var icon_f6d9620b825d82676d850975113e606b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c256f4de9ef2f8b48d0d2fa1b228dbdd.setIcon(icon_f6d9620b825d82676d850975113e606b);
#
#
#         var popup_052502e407b664a7fe3080b40d002c2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12e1d25085170b5dce40efdb65955f51 = $(`&lt;div id=&quot;html_12e1d25085170b5dce40efdb65955f51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:150p

# %%
# make the map
m = folium.Map(location=[center_lat,center_lon], 
               zoom_start=2,
               attr = '国土地理院')

# add basemaps
folium.TileLayer(name='2007年以降',tiles='https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1987年～1990年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1984年～1986年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1979年～1983年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1974年～1978年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1961年～1969年',tiles='https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png',attr='国土地理院').add_to(m)

# basemapが選べるボタンをマップに足す
folium.LayerControl().add_to(m)

# add points
for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, popup='<div style="width:150px">'+row['description']+'</div>', tooltip=row['name'],icon=folium.Icon(color=row['color'])).add_to(m)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6d5a9a274d86a87cb5f722b249c5e20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6d5a9a274d86a87cb5f722b249c5e20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6d5a9a274d86a87cb5f722b249c5e20 = L.map(
#                 &quot;map_a6d5a9a274d86a87cb5f722b249c5e20&quot;,
#                 {
#                     center: [6.556941838600001, 54.451263301],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1c8fd84d98da33e672db8f5ec41746b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6d5a9a274d86a87cb5f722b249c5e20);
#
#
#             var tile_layer_4c9a8942006e8553da2456e62ff80fa2 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6d5a9a274d86a87cb5f722b249c5e20);
#
#
#             var tile_layer_fd27cf8093b13f8ca0d1996a7ff10373 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6d5a9a274d86a87cb5f722b249c5e20);
#
#
#             var tile_layer_7bae9864ebd495edeb229fa984e17543 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6d5a9a274d86a87cb5f722b249c5e20);
#
#
#             var tile_layer_3f808843d2ab32d55f58ff28698dfeac = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6d5a9a274d86a87cb5f722b249c5e20);
#
#
#             var tile_layer_16752fe389f59bf14b022c792d64db23 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6d5a9a274d86a87cb5f722b249c5e20);
#
#
#             var tile_layer_03cc9f528ed74e97240b303378cd78ab = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6d5a9a274d86a87cb5f722b249c5e20);
#
#
#             var layer_control_f014d3ad6e432898007d2f7225d70b4f = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b1c8fd84d98da33e672db8f5ec41746b,
#                     &quot;2007\u5e74\u4ee5\u964d&quot; : tile_layer_4c9a8942006e8553da2456e62ff80fa2,
#                     &quot;1987\u5e74\uff5e1990\u5e74&quot; : tile_layer_fd27cf8093b13f8ca0d1996a7ff10373,
#                     &quot;1984\u5e74\uff5e1986\u5e74&quot; : tile_layer_7bae9864ebd495edeb229fa984e17543,
#                     &quot;1979\u5e74\uff5e1983\u5e74&quot; : tile_layer_3f808843d2ab32d55f58ff28698dfeac,
#                     &quot;1974\u5e74\uff5e1978\u5e74&quot; : tile_layer_16752fe389f59bf14b022c792d64db23,
#                     &quot;1961\u5e74\u

# %%
感想
日本だけではなく、世界規模であっても真ん中を見つけて表示させることができた。地図系のアプリを開発できたら、便利に快適に旅行に行けると思った。
