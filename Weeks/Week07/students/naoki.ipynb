# %% [markdown]
# <font color ='red'># Food map</font>
# 麗澤大学近くの評価が高い飲食店を載せました！

# %% [markdown]
# 必要なライブラリをインポート

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %% [markdown]
# ファイルを読み込み

# %%
df=pd.read_csv('mydata2.csv')

# %% [markdown]
# うまく読めているか、チェック

# %%
df
# Out:
#        name description   latitude   longitude   color
# 0      まこと亭        とんかつ  35.840265  139.961808     red
# 1      にえもん         うなぎ  35.842213  139.956829   blue
# 2  魚問屋　魚一商店       居酒屋、魚  35.849031  139.954083   green
# 3  キッチンホーリー          洋食  35.844022  139.953396  purple
# 4      かしわ家          そば  35.840961  139.962322  orange
# 5      食堂果樹     カフェ、カレー  35.829967  139.964211    gray
# 6      うどん市         うどん  35.839847  139.947388   black
# 7       大阪屋         定食屋  35.823172  139.949135    pink
# 8        塩梅   とんかつ・ビフテキ  35.867282  139.966816   beige
# 9     ぶぶちゃん        韓国料理  35.827626  139.963898   white

# %% [markdown]
# 一応、データが変ではないかチェック

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         10 non-null     object
#  1   description  10 non-null     object
#  2   latitude     10 non-null     float64
#  3   longitude    10 non-null     float64
#  4   color        10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes

# %% [markdown]
# マップのズームを設定するためにマップの中心を求める

# %%
center_lat = df['latitude'].mean()
center_lon = df['longitude'].mean()

print(center_lat,center_lon)
# Out:
# 35.84043854 139.95798865999998

# %% [markdown]
# マップを作り、マーカーをうつコードを書いて、基本のマップを完成させる

# %%
m = folium.Map(location=[center_lat,center_lon], zoom_start=13)
for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon,popup='<div style="width:150px">'+row['description']+'</div>',tooltip=row['name'],icon=folium.Icon(color=row['color'] )).add_to(m)
    
m
# Out:
# /var/folders/qn/g35trx293n93yxfc9mtdl8cc0000gn/T/ipykernel_27864/544775491.py:4: UserWarning: color argument of Icon should be one of: {'darkgreen', 'beige', 'darkpurple', 'darkred', 'pink', 'blue', 'lightgray', 'purple', 'black', 'lightred', 'green', 'orange', 'white', 'cadetblue', 'lightblue', 'gray', 'darkblue', 'lightgreen', 'red'}.
#   folium.Marker(latlon,popup='<div style="width:150px">'+row['description']+'</div>',tooltip=row['name'],icon=folium.Icon(color=row['color'] )).add_to(m)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9cf89e7e2fbf3cdc09235d31cff8c0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9cf89e7e2fbf3cdc09235d31cff8c0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9cf89e7e2fbf3cdc09235d31cff8c0d = L.map(
#                 &quot;map_b9cf89e7e2fbf3cdc09235d31cff8c0d&quot;,
#                 {
#                     center: [35.84043854, 139.95798865999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ae0fd56269b385036a89ab64ce31eb2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b9cf89e7e2fbf3cdc09235d31cff8c0d);
#
#
#             var marker_ae717250eefa4999d07df5c45610b61b = L.marker(
#                 [35.84026488, 139.9618076],
#                 {}
#             ).addTo(map_b9cf89e7e2fbf3cdc09235d31cff8c0d);
#
#
#             var icon_ffbb855b7ac2eae7ea82c2553fef6c68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ae717250eefa4999d07df5c45610b61b.setIcon(icon_ffbb855b7ac2eae7ea82c2553fef6c68);
#
#
#         var popup_67f9057d889845e83be16e1740415518 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd5e23efc17fde85cceb6ff2273cc826 = $(`&lt;div id=&quot;html_bd5e23efc17fde85cceb6ff2273cc826&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:150px&quot;&gt;とんかつ&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_67f9057d889845e83be16e1740415518.setContent(html_bd5e23efc17fde85cceb6ff2273cc826);
#
#
#
#         marker_ae717250eefa4999d07df5c45610b61b.bindPopup(popup_67f9057d889845e83be16e1740415518)
#         ;
#
#
#
#
#             marker_ae717250eefa4999d07df5c45610b61b.bindTooltip(
#                 `&lt;div&gt;
#                      まこと亭
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c3d3bb241d0501758c3bbd01558c5547 = L.marker(
#                 [35.84221306, 139.9568294],
#                 {}
#             ).addTo(map_b9cf89e7e2fbf3cdc09235d31cff8c0d);
#
#
#             var icon_31872140287ef8ba3ef04ccd5d2afe40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue &quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c3d3bb241d0501758c3bbd01558c5547.setIcon(icon_31872140287ef8ba3ef04ccd5d2afe40);
#
#
#         var popup_1b6c983561868fe70f4fee4f88d266d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e36a30dd359f54ce9e1197271b6a0f61 = $(`&lt;div id=&quot;html_e36a30dd359f54ce9e1197271b6a0f61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:150px&quot;&gt;うなぎ&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_1b6c983561868fe70f4fee4f88d266d8.setContent(html_e36a30dd359f54ce9e1197271b6a0f61);
#
#
#
#         marker_c3d3bb241d0501758c3bbd01558c5547.bindPopup(popup_1b6c983561868fe70f4fee4f88d266d8)
#         ;
#
#
#
#
#             marker_c3d3bb241d0501758c3bbd01558c5547.bindTooltip(
#                 `&lt;div&gt;
#                      にえもん
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aa03f7046a9c5241ff4417488ff17e4b = L.marker(
#                 [35.84903133, 139.9540828],
#                 {}
#             ).addTo(map_b9cf89e7e2fbf3cdc09235d31cff8c0d);
#
#
#             var icon_352542b9e54b152ae0d359f0f4a43318 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aa03f7046a9c5241ff4417488ff17e4b.setIcon(icon_352542b9e54b152ae0d359f0f4a43318);
#
#
#         var popup_ff139fbc2760e845a17e1eaaa69ed2cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dcf55de869ae07dc5334b2b931ca10f7 = $(`&lt;div id=&quot;html_dcf55de869ae07dc5334b2b931ca10f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:150px&quot;&gt;居酒屋、魚&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_ff13

# %% [markdown]
# さっきのマップに衛星写真を追加するコードを追加して再度コードを書く

# %%
m = folium.Map(location=[center_lat,center_lon], zoom_start=13, attr = '国土地理院')

folium.TileLayer(name='2007年以降',tiles='https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1987年～1990年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1984年～1986年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1979年～1983年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1974年～1978年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1961年～1969年',tiles='https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png',attr='国土地理院').add_to(m)

folium.LayerControl().add_to(m)

for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon,popup='<div style="width:150px">'+row['description']+'</div>',tooltip=row['name'],icon=folium.Icon(color=row['color'] )).add_to(m)
    
m
# Out:
# /var/folders/qn/g35trx293n93yxfc9mtdl8cc0000gn/T/ipykernel_27864/2064417622.py:14: UserWarning: color argument of Icon should be one of: {'darkgreen', 'beige', 'darkpurple', 'darkred', 'pink', 'blue', 'lightgray', 'purple', 'black', 'lightred', 'green', 'orange', 'white', 'cadetblue', 'lightblue', 'gray', 'darkblue', 'lightgreen', 'red'}.
#   folium.Marker(latlon,popup='<div style="width:150px">'+row['description']+'</div>',tooltip=row['name'],icon=folium.Icon(color=row['color'] )).add_to(m)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01455f926d2cd1e502a4510b3041879c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01455f926d2cd1e502a4510b3041879c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01455f926d2cd1e502a4510b3041879c = L.map(
#                 &quot;map_01455f926d2cd1e502a4510b3041879c&quot;,
#                 {
#                     center: [35.84043854, 139.95798865999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_021bf7b43723e0490e9314d4bbfabeb3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01455f926d2cd1e502a4510b3041879c);
#
#
#             var tile_layer_b12c72948d4184bb6fc0103461a6148d = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01455f926d2cd1e502a4510b3041879c);
#
#
#             var tile_layer_3eab66ee6633c290568f6fcd3f9e6652 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01455f926d2cd1e502a4510b3041879c);
#
#
#             var tile_layer_adf38eaf9b5dcc15c78cb04e01dfb73a = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01455f926d2cd1e502a4510b3041879c);
#
#
#             var tile_layer_66347ec8f2e5e636af6c2079e09c5146 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01455f926d2cd1e502a4510b3041879c);
#
#
#             var tile_layer_16a4d17e7364e163a35bb2e62c80d025 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01455f926d2cd1e502a4510b3041879c);
#
#
#             var tile_layer_95b45c5c6fc4487a2709d6bf80461f26 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01455f926d2cd1e502a4510b3041879c);
#
#
#             var layer_control_5fae82c0b5802aac547fe7ef3df2c7dd = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_021bf7b43723e0490e9314d4bbfabeb3,
#                     &quot;2007\u5e74\u4ee5\u964d&quot; : tile_layer_b12c72948d4184bb6fc0103461a6148d,
#                     &quot;1987\u5e74\uff5e1990\u5e74&quot; : tile_layer_3eab66ee6633c290568f6fcd3f9e6652,
#                     &quot;1984\u5e74\uff5e1986\u5e74&quot; : tile_layer_adf38eaf9b5dcc15c78cb04e01dfb73a,
#                     &quot;1979\u5e74\uff5e1983\u5e74&quot; : tile_layer_66347ec8f2e5e636af6c2079e09c5146,
#                     &quot;1974\u5e74\uff5e1978\u5e74&quot; : tile_layer_16a4d17e7364e163a35bb2e62c80d025,
#                     &quot;1961\u5e74\

# %% [markdown]
# ##　感想
# 今回の課題は衛星写真が特にインパクトがあって見た目の迫力はすごいけど、コード自体はすごい難しいわけではなくて比較的、簡単なコードでも、これだけのものが作れると知って驚きました！それと自分の力もだんだんついてきている実感があるのでとても嬉しい！
