# %% [markdown]
# You have been hired as an intern for Map Kings, a new startup that delivers map-based solutions. You are tasked to develop a Jupyter notebook for a client that wants to create a community profile for xxx city.
#
# Specifically, the client wants:
#
# A choropleth map of Kashiwa City that shows where people from different job types live.
#
# ## Steps
#
# ### Step 1: import libraries
# - geopandas
# - contextily
# - pandas
#
# ### Step 2: get the data
#
# There are two datasets required to make this project work.
#
# 1. The Kashiwa City chocho shapefile
# 1. 職業（大分類）別就業者数 for Chiba Prefecture
#
# Both are available from the e-Stat website.
#
# Hint: When you import the Chiba Prefecture work data, make sure to unzip the file first.
#
# ### Step 3: import the data and inspect it
#
# 1. use geopandas to import the shapefile (zip)
# 1. use pandas to import the work data (csv)
#
# Hint: when importing the work data, make sure to add the encoding argument:
# ```python
# df = pd.read_csv('tblT001104C12.csv', encoding='cp932')
# ```
#
# ### Step 4: join the data

# %%
import geopandas as gpd
import contextily as ctx
import pandas as pd

# %%
chiba = gpd.read_file('B002005212020DDSWC12217.zip')

# %%
chiba.plot()
# Out:
# <AxesSubplot: >

# %%
chiba_work = pd.read_csv('tblT001104C12.csv', encoding='cp932')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 chiba_work = pd.read_csv('tblT001104C12.csv', encoding='cp932')
#
# File ~/opt/anaconda3/envs/geos/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/geos/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
chiba['KEY_CODE'] = chiba['KEY_CODE'].astype(int)

# %%
chiba_work['KEY_CODE'] = chiba_work['KEY_CODE'].astype(int)

# %%
chiba

# %%
chiba_work.info()

# %%
chiba_work_merge = chiba.merge(chiba_work,on='KEY_CODE')

# %%
chiba_work_merge
