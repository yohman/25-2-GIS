# %%
import geopandas as gpd
import contextily as ctx
import plotly.express as px

# set font
import matplotlib as mpl

# for Mac
mpl.rc('font',family='Hiragino Maru Gothic Pro')

# for PC
mpl.rc('font',family='MS Gothic')

# %%
import geopandas as gpd

gdf = gpd.read_file('B002005212020XYSWC11110.zip')

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   KEY_CODE   1781 non-null   object
#  1   PREF       1781 non-null   object
#  2   CITY       1781 non-null   object
#  3   K_AREA     1781 non-null   object
#  4   S_AREA     1781 non-null   object
#  5   PREF_NAME  1781 non-null   object
#  6   CITY_NAME  1781 non-null   object
#  7   S_NAME     1781 non-null   object
#  8   KIGO_E     0 non-null      float64
#  9   HCODE      1781 non-null   int64
#  10  AREA       1781 non-null   float64
#  11  PERIMETER  1781 non-null   float64
#  12  KIHON1     1781 non-null   object
#  13  DUMMY1     1781 non-null   object
#  14  KIHON2     1781 non-null   object
#  15  KIHON3     1781 non-null   object
#  16  C1         1781 non-null   int64
#  17  C2         1781 non-null   int64
#  18  DUMMY2     1781 non-null   object
# ...

# %%
gdf.head()
# Out:
#        KEY_CODE PREF CITY     K_AREA   S_AREA PREF_NAME CITY_NAME S_NAME
# 0    1111000011   11  110  007003020    00011       埼玉県  さいたま市岩槻区  本町三丁目  \
# 1  111100002101   11  110  007003010  0002101       埼玉県  さいたま市岩槻区  本町三丁目
# 2  111100002102   11  110  007003030  0002102       埼玉県  さいたま市岩槻区  本町三丁目
# 3  111100002103   11  110  007003040  0002103       埼玉県  さいたま市岩槻区  本町三丁目
# 4  111100002104   11  110  007003050  0002104       埼玉県  さいたま市岩槻区  本町三丁目
#
#    KIGO_E  HCODE  ...      KEYCODE1  JINKO SETAI KEN_OLD CITY_OLD      X_CODE
# 0     NaN   8101  ...  1100001-1-00    133    67      11      110  139.694154  \
# 1     NaN   8101  ...  1100002-1-01     12     4      11      110  139.694032
# 2     NaN   8101  ...  1100002-1-02      4     2      11      110  139.694947
# 3     NaN   8101  ...  1100002-1-03      3     3      11      110  139.695438
# 4     NaN   8101  ...  1100002-1-04     59    29      11      110  139.696284
#
#       Y_CODE      KCODE1  CCODE1
# ...

# %%
ax = gdf.plot()

# %%
# population map
ax = gdf.plot(column='JINKO',
         legend=True)

# %%
# population map
ax = gdf.plot(figsize=(10,10),
         column='JINKO',
         legend=True)

# %%
# population map
ax = gdf.plot(figsize=(10,10),
         column='JINKO',
         legend=True,
         cmap='autumn_r')

# %%
# population map
ax = gdf.plot(figsize=(10,10),
         column='JINKO',
         legend=True,
         cmap='autumn_r',
         edgecolor='black',
         linewidth=0.1)

# %%
# population map
ax = gdf.plot(figsize=(10,10),
         column='JINKO',
         legend=True,
         cmap='autumn_r',
         edgecolor='black',
         linewidth=0.1)

# hide axes
ax.axis('off')
# Out:
# (-16711.405539597756,
#  -6389.973067736601,
#  -14011.781384134581,
#  964.670125048276)

# %%
# Out:
#   Cell In[29], line 3
#     - source=cx.providers.CartoDB.Positron
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# population map
ax = gdf.plot(figsize=(10,10),
         column='JINKO',
         legend=True,
         cmap='autumn_r',
         edgecolor='black',
         linewidth=0.1)

# hide axes
ax.axis('off')

# title
ax.set_title('さいたま市岩槻区の人口(2020)',fontsize=24)
# Out:
# Text(0.5, 1.0, 'さいたま市岩槻区の人口(2020)')

# %%
import contextily as cx

# %%
# change projection for your data to match basemap
gdf=gdf.to_crs(3857)

# %%
# population map
ax = gdf.plot(figsize=(10,10),
         column='JINKO',
         legend=True,
         cmap='autumn_r',
         edgecolor='black',
         linewidth=0.1,
         alpha=0.8)

# hide axes
ax.axis('off')

# title
ax.set_title('さいたま市岩槻区の人口(2020)',fontsize=24);

# %%
# population map
ax = gdf.plot(figsize=(10,10),
         column='SETAI',
         legend=True,
         cmap='autumn_r',
         edgecolor='black',
         linewidth=0.1,
         alpha=0.8)

# hide axes
ax.axis('off')

# title
ax.set_title('さいたま市岩槻区の世帯(2020)',fontsize=24);

# %%
# population map
ax = gdf.head(10).plot(figsize=(5,5),
         column='JINKO',
         legend=True,
         cmap='autumn_r',
         edgecolor='black',
         linewidth=1,
         alpha=0.8)

# hide axes
ax.axis('off')

# title
ax.set_title('さいたま市岩槻区の人口の多い街トップ10',fontsize=24);

# %%
# population map
ax = gdf.head(10).plot(figsize=(5,5),
         column='SETAI',
         legend=True,
         cmap='autumn_r',
         edgecolor='black',
         linewidth=1,
         alpha=0.8)

# hide axes
ax.axis('off')

# title
ax.set_title('さいたま市岩槻区の世帯の多い街トップ10',fontsize=24);

# %% [markdown]
# 僕が住んでいる埼玉県さいたま市岩槻区のデータを使い、人口と世帯のマップを作成しました。
# このようにデータを使うことで社内や取引先、お客様に情報を分かりやすく提供することが出来ると思います。
