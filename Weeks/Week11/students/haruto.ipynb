# %%
import geopandas as gpd
import pandas as pd
import contextily as ctx
import plotly.express as px
import contextily as cx
import numpy as np

# set font
import matplotlib as mpl

# for Mac
mpl.rc('font',family='Hiragino Maru Gothic Pro')

# for PC
# mpl.rc('font',family='MS Gothic')

# %%
niigatamesh1=gpd.read_file('data/SDDSWS5537')
niigatamesh2=gpd.read_file('data/SDDSWS5538')
niigatamesh3=gpd.read_file('data/SDDSWS5539')
niigatamesh4=gpd.read_file('data/SDDSWS5638')
niigatamesh5=gpd.read_file('data/SDDSWS5639')
niigatamesh6=gpd.read_file('data/SDDSWS5738')
niigatamesh7=gpd.read_file('data/SDDSWS5739')

# %%
niigatamesh = gpd.pd.concat([niigatamesh1,niigatamesh2,niigatamesh3,niigatamesh4,niigatamesh5,niigatamesh6,niigatamesh7])

# %%
niigatamesh.plot(figsize=(20,20),edgecolor='white',linewidth=0.1)
# Out:
# <Axes: >

# %%
niigatadata1 = pd.read_csv('data/tblT001100S5537', encoding='cp932')
niigatadata2 = pd.read_csv('data/tblT001100S5538', encoding='cp932')
niigatadata3 = pd.read_csv('data/tblT001100S5539', encoding='cp932')
niigatadata4 = pd.read_csv('data/tblT001100S5638', encoding='cp932')
niigatadata5 = pd.read_csv('data/tblT001100S5639', encoding='cp932')
niigatadata6 = pd.read_csv('data/tblT001100S5738', encoding='cp932')
niigatadata7 = pd.read_csv('data/tblT001100S5739', encoding='cp932')

# %%
niigatadata1=niigatadata1[1:]
niigatadata2=niigatadata2[1:]
niigatadata3=niigatadata3[1:]
niigatadata4=niigatadata4[1:]
niigatadata5=niigatadata5[1:]
niigatadata6=niigatadata6[1:]
niigatadata7=niigatadata7[1:]

# %%
niigatadata1=niigatadata1.replace('*',np.nan)
niigatadata2=niigatadata2.replace('*',np.nan)
niigatadata3=niigatadata3.replace('*',np.nan)
niigatadata4=niigatadata4.replace('*',np.nan)
niigatadata5=niigatadata5.replace('*',np.nan)
niigatadata6=niigatadata6.replace('*',np.nan)
niigatadata7=niigatadata7.replace('*',np.nan)

# %%
niigatadata = pd.concat([niigatadata1,niigatadata2,niigatadata3,niigatadata4,niigatadata5,niigatadata6,niigatadata7])

# %%
niigatadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9608 entries, 1 to 737
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    9608 non-null   float64
#  1   HTKSYORI    9608 non-null   float64
#  2   HTKSAKI     1209 non-null   float64
#  3   GASSAN      979 non-null    object
#  4   T001100001  9608 non-null   object
#  5   T001100002  9608 non-null   object
#  6   T001100003  9608 non-null   object
#  7   T001100004  8399 non-null   object
#  8   T001100005  8399 non-null   object
#  9   T001100006  8399 non-null   object
#  10  T001100007  8399 non-null   object
#  11  T001100008  8399 non-null   object
#  12  T001100009  8399 non-null   object
#  13  T001100010  8399 non-null   object
#  14  T001100011  8399 non-null   object
#  15  T001100012  8399 non-null   object
#  16  T001100013  8399 non-null   object
#  17  T001100014  8399 non-null   object
#  18  T001100015  8399 non-null   object
#  19  T001100016  8399 non-null   object
#  20  T001100017  8399 non-null   object
#  21  T001100018  8399 non-null   object
#  22  T001100019  8399 non-null   object
#  23  T001100020  8399 non-null   object
#  24  T001100021  8399 non-null   object
#  25  T001100022  8399 non-null   object
#  26  T001100023  8399 non-null   object
#  27  T001100024  8399 non-null   object
#  28  T001100025  8399 non-null   object
#  29  T001100026  8399 non-null   object
#  30  T001100027  8399 non-null   object
#  31  T001100028  8399 non-null   object
#  32  T001100029  8399 non-null   object
#  33  T001100030  8399 non-null   object
#  34  T001100031  8399 non-null   object
#  35  T001100032  8399 non-null   object
#  36  T001100033  8399 non-null   object
#  37  T001100034  9608 non-null   object
#  38  T001100035  9608 non-null   object
#  39  T001100036  8399 non-null   object
#  40  T001100037  8399 non-null   object
#  41  T001100038  8399 non-null   object
#  42  T001100039  8399 non-null   object
#  43  T001100040  8399 non-null   object
#  44  T001100041  8399 non-null   object
#  45  T001100042  8399 non-null   object
#  46  T001100043  8399 non-null   object
#  47  T001100044  8399 non-null   object
#  48  T001100045  8399 non-null   object
#  49  T001100046  8399 non-null   object
#  50  T001100047  8399 non-null   object
#  51  T001100048  8399 non-null   object
#  52  T001100049  8399 non-null   object
#  53  T001100050  8399 non-null   object
# dtypes: float64(3), object(51)
# memory usage: 4.0+ MB

# %%
niigatadata.columns
# Out:
# Index(['KEY_CODE', 'HTKSYORI', 'HTKSAKI', 'GASSAN', 'T001100001', 'T001100002',
#        'T001100003', 'T001100004', 'T001100005', 'T001100006', 'T001100007',
#        'T001100008', 'T001100009', 'T001100010', 'T001100011', 'T001100012',
#        'T001100013', 'T001100014', 'T001100015', 'T001100016', 'T001100017',
#        'T001100018', 'T001100019', 'T001100020', 'T001100021', 'T001100022',
#        'T001100023', 'T001100024', 'T001100025', 'T001100026', 'T001100027',
#        'T001100028', 'T001100029', 'T001100030', 'T001100031', 'T001100032',
#        'T001100033', 'T001100034', 'T001100035', 'T001100036', 'T001100037',
#        'T001100038', 'T001100039', 'T001100040', 'T001100041', 'T001100042',
#        'T001100043', 'T001100044', 'T001100045', 'T001100046', 'T001100047',
#        'T001100048', 'T001100049', 'T001100050'],
#       dtype='object')

# %%
niigatadata.columns[4:]
# Out:
# Index(['T001100001', 'T001100002', 'T001100003', 'T001100004', 'T001100005',
#        'T001100006', 'T001100007', 'T001100008', 'T001100009', 'T001100010',
#        'T001100011', 'T001100012', 'T001100013', 'T001100014', 'T001100015',
#        'T001100016', 'T001100017', 'T001100018', 'T001100019', 'T001100020',
#        'T001100021', 'T001100022', 'T001100023', 'T001100024', 'T001100025',
#        'T001100026', 'T001100027', 'T001100028', 'T001100029', 'T001100030',
#        'T001100031', 'T001100032', 'T001100033', 'T001100034', 'T001100035',
#        'T001100036', 'T001100037', 'T001100038', 'T001100039', 'T001100040',
#        'T001100041', 'T001100042', 'T001100043', 'T001100044', 'T001100045',
#        'T001100046', 'T001100047', 'T001100048', 'T001100049', 'T001100050'],
#       dtype='object')

# %%
niigatadata[niigatadata.columns[4:]]
# Out:
#     T001100001 T001100002 T001100003 T001100004 T001100005 T001100006
# 1          313        152        161         27         15         12  \
# 2          244        123        121         17         11          6
# 3           17          9          8          2          1          1
# 4          137         68         69         10          4          6
# 5           19         10          9          1          1          0
# ..         ...        ...        ...        ...        ...        ...
# 733          3          1          2          3          2          1
# 734         70         31         39          3          1          2
# 735         14          8          6          0          0          0
# 736          7          4          3          0          0          0
# 737         26         12         14          4          2          2
#
#     T001100007 T001100008 T001100009 T001100010  ... T001100041 T001100042
# 1          286        137        149        172  ...          3          2  \
# 2          223        111        112        144  ...          1          2
# 3           15          8          7         11  ...          0          1
# 4          127         64         63         75  ...          2          0
# 5           18          9          9         13  ...          1          0
# ..         ...        ...        ...        ...  ...        ...        ...
# 733         13          6          7          9  ...          0          1
# 734         67         30         37         35  ...          0          2
# 735         14          8          6          4  ...          0          0
# 736         11          5          6          6  ...          0          0
# 737         22         10         12         13  ...          0          1
#
#     T001100043 T001100044 T001100045 T001100046 T001100047 T001100048
# 1           84         55         29          5         72          0  \
# 2           61         41         20          3         54          0
# 3            4          3          1          0          3          0
# 4           44         32         12          4         33          0
# 5            6          5          1          0          3          0
# ..         ...        ...        ...        ...        ...        ...
# 733          4          2          2          1          3          0
# 734         19          9         10          0         21          0
# 735          4          3          1          0          6          0
# 736          3          2          1          0          4          0
# 737          6          3          3          2          7          0
#
#     T001100049 T001100050
# 1           13         11
# 2            7         10
# 3            0          0
# 4            5         10
# 5            0          2
# ..         ...        ...
# 733          0          0
# 734          3          4
# 735          2          0
# 736          2          0
# 737          2          1
#
# [9608 rows x 50 columns]

# %%
niigatadata[niigatadata.columns[4:]].astype(float)
# Out:
#      T001100001  T001100002  T001100003  T001100004  T001100005  T001100006
# 1         313.0       152.0       161.0        27.0        15.0        12.0  \
# 2         244.0       123.0       121.0        17.0        11.0         6.0
# 3          17.0         9.0         8.0         2.0         1.0         1.0
# 4         137.0        68.0        69.0        10.0         4.0         6.0
# 5          19.0        10.0         9.0         1.0         1.0         0.0
# ..          ...         ...         ...         ...         ...         ...
# 733         3.0         1.0         2.0         3.0         2.0         1.0
# 734        70.0        31.0        39.0         3.0         1.0         2.0
# 735        14.0         8.0         6.0         0.0         0.0         0.0
# 736         7.0         4.0         3.0         0.0         0.0         0.0
# 737        26.0        12.0        14.0         4.0         2.0         2.0
#
#      T001100007  T001100008  T001100009  T001100010  ...  T001100041
# 1         286.0       137.0       149.0       172.0  ...         3.0  \
# 2         223.0       111.0       112.0       144.0  ...         1.0
# 3          15.0         8.0         7.0        11.0  ...         0.0
# 4         127.0        64.0        63.0        75.0  ...         2.0
# 5          18.0         9.0         9.0        13.0  ...         1.0
# ..          ...         ...         ...         ...  ...         ...
# 733        13.0         6.0         7.0         9.0  ...         0.0
# 734        67.0        30.0        37.0        35.0  ...         0.0
# 735        14.0         8.0         6.0         4.0  ...         0.0
# 736        11.0         5.0         6.0         6.0  ...         0.0
# 737        22.0        10.0        12.0        13.0  ...         0.0
#
#      T001100042  T001100043  T001100044  T001100045  T001100046  T001100047
# 1           2.0        84.0        55.0        29.0         5.0        72.0  \
# 2           2.0        61.0        41.0        20.0         3.0        54.0
# 3           1.0         4.0         3.0         1.0         0.0         3.0
# 4           0.0        44.0        32.0        12.0         4.0        33.0
# 5           0.0         6.0         5.0         1.0         0.0         3.0
# ..          ...         ...         ...         ...         ...         ...
# 733         1.0         4.0         2.0         2.0         1.0         3.0
# 734         2.0        19.0         9.0        10.0         0.0        21.0
# 735         0.0         4.0         3.0         1.0         0.0         6.0
# 736         0.0         3.0         2.0         1.0         0.0         4.0
# 737         1.0         6.0         3.0         3.0         2.0         7.0
#
#      T001100048  T001100049  T001100050
# 1           0.0        13.0        11.0
# 2           0.0         7.0        10.0
# 3           0.0         0.0         0.0
# 4           0.0         5.0        10.0
# 5           0.0         0.0         2.0
# ..          ...         ...         ...
# 733         0.0         0.0         0.0
# 734         0.0         3.0         4.0
# 735         0.0         2.0         0.0
# 736         0.0         2.0         0.0
# 737         0.0         2.0         1.0
#
# [9608 rows x 50 columns]

# %%
niigatadata[niigatadata.columns[4:]]=niigatadata[niigatadata.columns[4:]].astype(float)

# %%
niigatadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9608 entries, 1 to 737
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    9608 non-null   float64
#  1   HTKSYORI    9608 non-null   float64
#  2   HTKSAKI     1209 non-null   float64
#  3   GASSAN      979 non-null    object
#  4   T001100001  9608 non-null   float64
#  5   T001100002  9608 non-null   float64
#  6   T001100003  9608 non-null   float64
#  7   T001100004  8399 non-null   float64
#  8   T001100005  8399 non-null   float64
#  9   T001100006  8399 non-null   float64
#  10  T001100007  8399 non-null   float64
#  11  T001100008  8399 non-null   float64
#  12  T001100009  8399 non-null   float64
#  13  T001100010  8399 non-null   float64
#  14  T001100011  8399 non-null   float64
#  15  T001100012  8399 non-null   float64
#  16  T001100013  8399 non-null   float64
#  17  T001100014  8399 non-null   float64
#  18  T001100015  8399 non-null   float64
#  19  T001100016  8399 non-null   float64
#  20  T001100017  8399 non-null   float64
#  21  T001100018  8399 non-null   float64
#  22  T001100019  8399 non-null   float64
#  23  T001100020  8399 non-null   float64
#  24  T001100021  8399 non-null   float64
#  25  T001100022  8399 non-null   float64
#  26  T001100023  8399 non-null   float64
#  27  T001100024  8399 non-null   float64
#  28  T001100025  8399 non-null   float64
#  29  T001100026  8399 non-null   float64
#  30  T001100027  8399 non-null   float64
#  31  T001100028  8399 non-null   float64
#  32  T001100029  8399 non-null   float64
#  33  T001100030  8399 non-null   float64
#  34  T001100031  8399 non-null   float64
#  35  T001100032  8399 non-null   float64
#  36  T001100033  8399 non-null   float64
#  37  T001100034  9608 non-null   float64
#  38  T001100035  9608 non-null   float64
#  39  T001100036  8399 non-null   float64
#  40  T001100037  8399 non-null   float64
#  41  T001100038  8399 non-null   float64
#  42  T001100039  8399 non-null   float64
#  43  T001100040  8399 non-null   float64
#  44  T001100041  8399 non-null   float64
#  45  T001100042  8399 non-null   float64
#  46  T001100043  8399 non-null   float64
#  47  T001100044  8399 non-null   float64
#  48  T001100045  8399 non-null   float64
#  49  T001100046  8399 non-null   float64
#  50  T001100047  8399 non-null   float64
#  51  T001100048  8399 non-null   float64
#  52  T001100049  8399 non-null   float64
#  53  T001100050  8399 non-null   float64
# dtypes: float64(53), object(1)
# memory usage: 4.0+ MB

# %%
niigatamesh['KEY_CODE']=niigatamesh['KEY_CODE'].astype(float)

# %%
niigatamesh = niigatamesh.merge(niigatadata, on='KEY_CODE')

# %%
niigatamesh.sample(5)
# Out:
#         KEY_CODE MESH1_ID MESH2_ID MESH3_ID  OBJ_ID
# 242   55370246.0     5537       02       46     247  \
# 8276  56396233.0     5639       62       33    5034
# 1052  55375719.0     5537       57       19    3320
# 4689  55394719.0     5539       47       19    3920
# 6354  56387214.0     5638       72       14    2915
#
#                                                geometry  HTKSYORI  HTKSAKI
# 242   POLYGON ((137.33750 36.70000, 137.32500 36.700...       0.0      NaN  \
# 8276  POLYGON ((139.30000 37.85833, 139.28750 37.858...       0.0      NaN
# 1052  POLYGON ((138.00000 37.09167, 137.98750 37.091...       0.0      NaN
# 4689  POLYGON ((140.00000 37.00833, 139.98750 37.008...       0.0      NaN
# 6354  POLYGON ((138.31250 37.92500, 138.30000 37.925...       1.0      NaN
#
#         GASSAN  T001100001  ...  T001100041  T001100042  T001100043
# 242        NaN       882.0  ...         9.0         1.0       270.0  \
# 8276       NaN        50.0  ...         1.0         0.0        12.0
# 1052       NaN       979.0  ...        10.0        10.0       250.0
# 4689       NaN        66.0  ...         0.0         1.0        19.0
# 6354  56387213        48.0  ...         0.0         0.0        19.0
#
#       T001100044  T001100045  T001100046  T001100047  T001100048  T001100049
# 242        230.0        40.0        19.0       189.0         3.0        35.0  \
# 8276         4.0         8.0         1.0        13.0         0.0         2.0
# 1052       191.0        59.0        27.0       199.0         6.0        43.0
# 4689        14.0         5.0         2.0        15.0         0.0         1.0
# 6354        12.0         7.0         0.0        17.0         0.0         1.0
#
#       T001100050
# 242         56.0
# 8276         2.0
# 1052        50.0
# 4689         4.0
# 6354         4.0
#
# [5 rows x 59 columns]

# %%
niigatamesh=niigatamesh.to_crs(3857)

# %%
niigatamesh.plot(column='T001100031')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
import geopandas as gpd
from matplotlib.pyplot import plot

# %%
import geopandas as gpd
import contextily as ctx
import plotly.express as px
import matplotlib as mpl
mpl.rc('font',family='Hiragino Maru Gothic Pro')

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# GeoDataFrameを読み込むなどの前処理を行う
# ...

# プロットするためのMatplotlibの図（Figure）と軸（Axes）オブジェクトを作成
fig, ax = plt.subplots(figsize=(10, 10))

# Geopandasのメソッドを使用して地理データをプロットする
gdf.plot(ax=ax)

# 軸（Axes）オプションの設定などを行う
# ...

# プロットの表示
plt.show()

# %%
前回の授業でやった範囲は大体できたんですが最後のweek９のところでつまずいてしまいできませんでした。僕もチャットGTPを使って質問してみると教えてくれるのに驚きました。
# Out:
#   Cell In[49], line 1
#     前回の授業でやった範囲は大体できたんですが最後のweek９のところでつまずいてしまいできませんでした。僕もチャットGTPを使って質問してみると教えてくれるのに驚きました。
#                                                       ^
# SyntaxError: invalid character '。' (U+3002)
