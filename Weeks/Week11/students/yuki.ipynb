# %%
import matplotlib as mpl
import geopandas as gpd
import pandas as pd
import contextily as ctx
import plotly.express as px
import contextily as cx
import numpy as np
import matplotlib as mpl
mpl.rc('font',family='MS Gothic')

# %%
ibaraki1 = gpd.read_file('data2/SDDSWS5339.zip')
ibaraki2 = gpd.read_file('data2/SDDSWS5340.zip')
ibaraki3 = gpd.read_file('data2/SDDSWS5439.zip')
ibaraki4 = gpd.read_file('data2/SDDSWS5440.zip')

# %%
gdf = gpd.read_file('data2/B002005212020DDSWC08202.zip')

# %%
ibarash= gpd.pd.concat([ibaraki1,ibaraki2,ibaraki3,ibaraki4])
ibarash.plot(figsize=(20,20),edgecolor='white',linewidth=0.1)
# Out:
# <Axes: >

# %%
ibaraki1=pd.read_csv('data2/tblT001100S5339.zip', encoding='cp932')
ibaraki2=pd.read_csv('data2/tblT001100S5340.zip', encoding='cp932')
ibaraki3=pd.read_csv('data2/tblT001100S5439.zip', encoding='cp932')
ibaraki4=pd.read_csv('data2/tblT001100S5440.zip', encoding='cp932')

# %%
ibaraki1=ibaraki1[1:]
ibaraki2=ibaraki2[1:]
ibaraki3=ibaraki3[1:]
ibaraki4=ibaraki4[1:]

# %%
ibaraki1=ibaraki1.replace('*' , np.nan)
ibaraki2=ibaraki2.replace('*' , np.nan)
ibaraki3=ibaraki3.replace('*' , np.nan)
ibaraki4=ibaraki4.replace('*' , np.nan)

# %%
ibarakidata=pd.concat([ibaraki1,ibaraki2,ibaraki3,ibaraki4])

# %%
ibarakidata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17232 entries, 1 to 3539
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    17232 non-null  float64
#  1   HTKSYORI    17232 non-null  float64
#  2   HTKSAKI     665 non-null    float64
#  3   GASSAN      561 non-null    object
#  4   T001100001  17232 non-null  object
#  5   T001100002  17232 non-null  object
#  6   T001100003  17232 non-null  object
#  7   T001100004  16567 non-null  object
#  8   T001100005  16567 non-null  object
#  9   T001100006  16567 non-null  object
#  10  T001100007  16567 non-null  object
#  11  T001100008  16567 non-null  object
#  12  T001100009  16567 non-null  object
#  13  T001100010  16567 non-null  object
#  14  T001100011  16567 non-null  object
#  15  T001100012  16567 non-null  object
#  16  T001100013  16567 non-null  object
#  17  T001100014  16567 non-null  object
#  18  T001100015  16567 non-null  object
# ...

# %%
ibarakidata.columns[4:]
# Out:
# Index(['T001100001', 'T001100002', 'T001100003', 'T001100004', 'T001100005',
#        'T001100006', 'T001100007', 'T001100008', 'T001100009', 'T001100010',
#        'T001100011', 'T001100012', 'T001100013', 'T001100014', 'T001100015',
#        'T001100016', 'T001100017', 'T001100018', 'T001100019', 'T001100020',
#        'T001100021', 'T001100022', 'T001100023', 'T001100024', 'T001100025',
#        'T001100026', 'T001100027', 'T001100028', 'T001100029', 'T001100030',
#        'T001100031', 'T001100032', 'T001100033', 'T001100034', 'T001100035',
#        'T001100036', 'T001100037', 'T001100038', 'T001100039', 'T001100040',
#        'T001100041', 'T001100042', 'T001100043', 'T001100044', 'T001100045',
#        'T001100046', 'T001100047', 'T001100048', 'T001100049', 'T001100050'],
#       dtype='object')

# %%
ibarakidata[ibarakidata.columns[4:]]
# Out:
#      T001100001 T001100002 T001100003 T001100004 T001100005 T001100006
# 1            52         29         23          1          1          0  \
# 2             3          2          1        NaN        NaN        NaN
# 3           147         68         79         11          4          7
# 4           783        394        389        105         57         48
# 5          3764       1791       1973        507        267        240
# ...         ...        ...        ...        ...        ...        ...
# 3535         14          7          7          0          0          0
# 3536        188         94         94         42         20         22
# 3537       2666       1330       1336        458        246        212
# 3538       2243       1081       1162        312        171        141
# 3539       1036        508        528         78         41         37
#
#      T001100007 T001100008 T001100009 T001100010  ... T001100041 T001100042
# ...

# %%
ibarakidata[ibarakidata.columns[4:]].astype(float)
# Out:
#       T001100001  T001100002  T001100003  T001100004  T001100005  T001100006
# 1           52.0        29.0        23.0         1.0         1.0         0.0  \
# 2            3.0         2.0         1.0         NaN         NaN         NaN
# 3          147.0        68.0        79.0        11.0         4.0         7.0
# 4          783.0       394.0       389.0       105.0        57.0        48.0
# 5         3764.0      1791.0      1973.0       507.0       267.0       240.0
# ...          ...         ...         ...         ...         ...         ...
# 3535        14.0         7.0         7.0         0.0         0.0         0.0
# 3536       188.0        94.0        94.0        42.0        20.0        22.0
# 3537      2666.0      1330.0      1336.0       458.0       246.0       212.0
# 3538      2243.0      1081.0      1162.0       312.0       171.0       141.0
# 3539      1036.0       508.0       528.0        78.0        41.0        37.0
#
# ...

# %%
ibarakidata[ibarakidata.columns[4:]]=ibarakidata[ibarakidata.columns[4:]].astype(float)

# %%
ibarakidata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17232 entries, 1 to 3539
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    17232 non-null  float64
#  1   HTKSYORI    17232 non-null  float64
#  2   HTKSAKI     665 non-null    float64
#  3   GASSAN      561 non-null    object
#  4   T001100001  17232 non-null  float64
#  5   T001100002  17232 non-null  float64
#  6   T001100003  17232 non-null  float64
#  7   T001100004  16567 non-null  float64
#  8   T001100005  16567 non-null  float64
#  9   T001100006  16567 non-null  float64
#  10  T001100007  16567 non-null  float64
#  11  T001100008  16567 non-null  float64
#  12  T001100009  16567 non-null  float64
#  13  T001100010  16567 non-null  float64
#  14  T001100011  16567 non-null  float64
#  15  T001100012  16567 non-null  float64
#  16  T001100013  16567 non-null  float64
#  17  T001100014  16567 non-null  float64
# ...

# %%
ibarash['KEY_CODE']=ibarash['KEY_CODE'].astype(float)

# %%
ibarash=ibarash.merge(ibarakidata, on='KEY_CODE')

# %%
ibarash=ibarash.to_crs(3857)

# %%
ibarash.plot(column='T001100001')
# Out:
# <Axes: >

# %%
ax = gdf.plot(figsize=(10,10),
         column='JINKO',
         legend=True,
         cmap='autumn_r',
         edgecolor='black',
         linewidth=0.1,
         alpha=0.8)
ax.axis('off')
ax.set_title('日立市の人口',fontsize=10);
cx.add_basemap(ax)
ibarash.plot(column='T001100001')
# Out:
# c:\Users\yuki_\miniconda3\envs\gis\Lib\site-packages\contextily\tile.py:581: UserWarning: The inferred zoom level of 29 is not valid for the current tile provider (valid zooms: 0 - 18).
#   warnings.warn(msg)
# <Axes: >

# %% [markdown]
# 色々調べたのですが地図の合わせ方がわからなかったです。
