# %%
import geopandas as gpd

# %%
gdf1 = gpd.read_file('tikeizu20170101/浦安市地形図20170101/建物－住居番号.shp')
gdf2 = gpd.read_file('tikeizu20170101/浦安市地形図20170101/背景.shp')

# %%
gdf1.head()
# Out:
#    CSAlign  CSRotate  CSSize CSText Gaiku Jukyo MachiAza Meisho Tatemono  \
# 0        4   48.3178     1.8   12-6    12     6    00117   ç¹      NaN
# 1        4   48.3178     1.8  12-12    12    12    00117   ç¹      NaN
# 2        4    0.0000     1.8   27-1    27     1    00114   l      NaN
# 3        4    0.0000     1.8   26-1    26     1    00114   l      NaN
# 4        4   36.8430     1.8     16    16   NaN    00117   ç¹      NaN
#
#                       geometry
# 0  POINT (6064.247 -41655.675)
# 1  POINT (6037.193 -41711.295)
# 2  POINT (4549.824 -40379.042)
# 3  POINT (4570.650 -40345.612)
# 4  POINT (5812.286 -42477.921)

# %%
gdf1.plot(column='MachiAza')
# Out:
# <AxesSubplot: >

# %%
gdf2.plot()
# Out:
# <AxesSubplot: >
